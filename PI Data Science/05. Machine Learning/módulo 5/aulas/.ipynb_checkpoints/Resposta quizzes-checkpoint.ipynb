# %% [markdown]
# # Resposta dos quizzes
#
# Quizzes de revisão de ML que fizemos no google forms ([partes 1 e 2 aqui](https://forms.gle/1ExfSud91VXHuUJWA) e [partes 3 e 4 aqui](https://forms.gle/vYH76SCmah2Xerh16))
#
# Nas aulas, discutimos cada uma das questões em detalhes, então recomendo vocês darem uma olhadinha lá também!
#
# Mas, para uma referência quanto à resposta, segue:

# %% [markdown]
# ____________
# ____________
# ____________

# %% [markdown]
# ## Partes 1 e 2
#
# ___________
#
# O processo teórico F é modelado pela função hipótese f, que é parametrizada. A determinação dos parâmetros é feita pelo algoritmo de aprendizagem com os dados na base de treino.
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
#
# Underfitting ocorre quando a hipótese se ajusta demasiadamente aos dados, ou seja, os ruídos/variações aleatórias da amostra de treino são incorporados pela hipótese
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
#
# Um modelo pode ser visto como uma representação do problema/contexto sob análise, muitas vezes com o objetivo de conferir poder preditivo
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# Um modelo deve ser avaliado através do cálculo de métricas de avaliação
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# Assumimos que existe uma função teórica F que de fato rege o comportamento do problema sob análise. Ou seja, esta função é o processo teórico que relaciona as features com o target
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# Os hiperparâmetros da hipótese são determinados pelo algoritmo de aprendizagem de modo a produzir a função específica dentro do conjunto de hipóteses  que melhor se ajusta aos dados
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# Um dos objetivos da aprendizagem é estimar a função teórica F a partir dos dados da população completa
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# Ao maximizar a métrica precision, queremos minimizar os falsos positivos
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# Os parâmetros da hipótese modificam o comportamento final do modelo, e seus valores devem ser determinados pelo cientista -- eles não são comumente aprendidos
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# Na aprendizagem supervisionada, os targets não fazem parte da base de dados (isto é, temos apenas features)
#
# <font color=red><b>Falso</b></font>
#
# ___________

# %% [markdown]
# __________________________________________

# %% [markdown]
# A regularização L1 (Lasso) não possibilita feature selection, pois os parâmetros podem são reduzidos a próximos de zero, mas não são anulados
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# Underfitting em geral ocorre quando as hipóteses acessíveis são demasiadamente complexas, de modo que as particularidades da base de treino são incorporadas pela hipótese
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# O número de dimensões das features (isto é, a quantidade de variáveis preditoras) deve sempre ser igual ao numero de dimensões do target
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# Técnicas de regularização têm como objetivo pragmático evitar underfitting
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# Um modelo com alto viés é um modelo com alto grau de underfitting; um modelo com alta variância é um modelo com alto grau de overfitting
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# A comparação das métricas de avaliações calculadas nas bases de treino e de teste é um boa forma de procurar por underfitting/overfitting
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# A regularização elastic net representa uma mistrua das regularizações L1 e L2
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# A função de custo/perda quantifica os erros que o modelo comete -- ou seja, a diferença entre os targets reais e os targets preditos
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# Overfitting ocorre quando a hipótese não é capaz de se ajustar aos dados, ou seja, não é capaz de extrair os padrões da base de treino
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# Overfitting em geral ocorre quando as hipóteses acessíveis são demasiadamente simples, incapazes de comportar os padrões presentes na base de treino
#
# <font color=red><b>Falso</b></font>
#
# ___________

# %% [markdown]
# ___________
#
# ___________
#
# ___________

# %% [markdown]
# ## Partes 3 e 4
#
# ___________
#
# Com a aplicação de técnicas de regularização, overfitting é evitado a partir da redução do espaço de hipóteses acessível
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# As regularizações L1 e L2 podem ser formuladas como problemas de otimização vinculados
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# Chamamos de target a variável resposta do problema -- que por sua vez é determinada/predita pelas features, que são as variáveis que caracterizam cada observação
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# A regularização L2 (Ridge) possibilita feature selection, pois é possível que parâmetros do modelo sejam zerados
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# É possível também formular a regularização como termos extras (penalizações) adicionados à função de custo original para o problema de otimização
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# As métricas de avaliação, parecidas com as funções de custo, comparam os targets preditos pelo modelo com os targets reais
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# A função de custo/perda deve sempre ser calculada com os dados de teste
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# Um problema de regressão tem target discreto; enquanto um problema de classificação tem garget contínuo
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# As métricas de avaliação não devem ser calculadas nos dados de treino
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# O único hiperparâmetro importante na regularização elastic net é o parâmetro de mistura (que indica a proporção relativa de L1/L2 na regularização completa)
#
# <font color=red><b>Falso</b></font>
#
# ___________

# %% [markdown]
# __________________________________________

# %% [markdown]
# A determinação do vetor de parâmetros que melhor se ajustam aos dados é explicitamente feita pela otimização de uma função de custo/perda (problema de otimização)
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# O target sempre deve ser uma variável continua
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# Os dados de treino devem ser utilizados apenas ao final da produção do modelo, para avaliação final da generalização
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# Quanto maior o parâmetro de força de regularização, maior é o espaço de hipóteses acessível
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# O tradeoff precision/recall refere-se ao tradeoff entre underfitting/overfitting
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# Quando os erros cometidos na base de treino são muito menores que os erros cometidos na base de teste, há overfitting
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# Para aferir a capacidade de generalização de um modelo, é muito importante que o volume de dados original sejam separados nas amostras de treino e de teste
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
#
# São exemplos de métricas de avaliação de classificação: MAE, RMSE, R^2, MSE, ...
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# São exemplos de métricas de avaliação de regressão: precision, recall, f1, AUC-ROC, ...
#
# <font color=red><b>Falso</b></font>
#
# ___________
#
# Ao maximizar a métrica recall, queremos minimizar os falsos negativos
#
#
# <font color=red><b>Verdadeiro</b></font>
#
# ___________
