# %% [markdown]
# <h1>Execercicios dentro da aula 1 10/Nov/2021 </h1>
# <p><p/>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

# %%
cv2.__version__
# Out:
# '4.5.3'

# %%
#carregando a imagem
img = cv2.imread("../img/lena_bw.png")

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (567, 567, 3)

# %% [markdown]
# Altura 567 Largura = 567 Camada = 3

# %%
df.shape
# Out:
# (567, 567, 3)

# %%
img[:,:,2] = 0

# %%
img[2,3]
# Out:
# array([159, 159, 159], dtype=uint8)

# %%
plt.imshow(img[:,:,0], cmap='gray')

# %%
plt.imshow(img, cmap='gray')
