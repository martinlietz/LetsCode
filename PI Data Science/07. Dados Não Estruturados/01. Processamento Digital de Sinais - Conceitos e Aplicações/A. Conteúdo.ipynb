# %% [markdown]
# <markdown translate="no" mathjax="" class="ng-tns-c364-40"><h1 id="processamento-digital-de-sinais-pds"><strong>Processamento Digital de Sinais (PDS)</strong></h1>
# <h2 id="conceitos-e-aplicações"><strong>Conceitos e Aplicações</strong></h2>
# <h3 id="índice">Índice:</h3>
# <ul>
# <li>1) O que é PDS;</li>
# <li>2) Conceitos;</li>
# <li>3) Passos fundamentais do PDS;</li>
# <li>4) Aplicações;</li>
# <li>5) PDS em Python</li>
# </ul>
# <h3 id="bibliografia">Bibliografia:</h3>
# <ul>
# <li><a href="https://www.amazon.com/exec/obidos/ASIN/0132146355/">Digital Signal Processing - Oppenheim, Alan V., and Ronald W. Schafer;</a></li>
# </ul>
# <h3 id="objetivos">Objetivos</h3>
# <p>Os principais objetivos deste material são:</p>
# <ul>
# <li>Apresentar os principais conceitos de processamento de sinais digitais;</li>
# <li>Mostrar aplicações para áreas das ciências e tecnologias;</li>
# <li>Fazer o processo de conversão de um sinal analógico para digital;</li>
# <li>Aplicar técnicas com Transformada de Fourier e construção de espectrograma com objetivo de extrair informação dos sinais.</li>
# </ul>
# <h3 id="1-o-que-é-pds"><strong>1) O que é PDS</strong></h3>
# <p>O Processamento Digital de Sinais (PDS) é a área de estudo que trabalha com processamento de sinais, podendo eles ser: som, imagens, textos entre outros.</p>
# <p>Para que os sinais possam ser analisados e processados, são usadas representações matemáticas destes, de modo que operações algébricas possam ser aplicadas em seu processamento, possibilitando, assim, a extração de informações.</p>
# <p>Neste material, vamos focar principalmente bno processamento de <strong>sinais de áudio</strong>. O processamento digital de imagens (PDI) e de linguagem natural (PLN) serão discutidos em materiais próprios.</p>
# <h3 id="o-que-é-um-sinal-de-áudio"><strong>O que é um sinal de Áudio?</strong></h3>
# <p>O <strong>som</strong> é um fenômeno ondulatório que consiste na perturbação (compressão e expansão) periódica de moléculas de ar sob a ação de alguma fonte sonora (voz, fone de ouvido, alto-falante, etc.)</p>
# <p>Tal perturbação viaja pelo ar através de ondas mecânicas esféricas, as <strong>ondas sonoras</strong>.</p>
# <p>No exemplo abaixo, a vibração do pistão produz uma pressão longitudinal no ar que é percebida como som pelo ouvido humano. </p>
# <p><img src="https://cdn.analyticsvidhya.com/wp-content/uploads/2019/07/originofsound.gif" alt="sinal de áudio"></p>
# <h3 id="2-conceitos"><strong>2) Conceitos</strong></h3>
# <p>A seguir, introduziremos algumas propriedades fundamentais do som.</p>
# <h4 id="frequência--f-"><em>Frequência <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-12-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mi>f</mi></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-49" style="width: 0.693em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.578em; height: 0px; font-size: 116%;"><span style="position: absolute; clip: rect(1.325em, 1000.58em, 2.589em, -999.997em); top: -2.181em; left: 0em;"><span class="mrow" id="MathJax-Span-50"><span class="mi" id="MathJax-Span-51" style="font-family: MathJax_Math-italic;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.06em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.187em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.33em; border-left: 0px solid; width: 0px; height: 1.203em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>f</mi></math></span></span><script type="math/tex" id="MathJax-Element-12"> f </script></em></h4>
# <p>Considere o som emitido por um diapasão (ferramenta utilizada para afinação de instrumentos musicais):</p>
# <img src="https://www2.ibb.unesp.br/nadi/Museu2_qualidade/Museu2_corpo_humano/Museu2_como_funciona/Museu_homem_nervoso/Museu2_homem_nervoso_audicao/Imagens/Som2.jpg" alt="drawing" width="400/">
#
# <p>O evento da variação de pressão de ar, apresentado na parte de cima da figura, pode ser representado num gráfico relacionando a amplitude da pressão sonora e o tempo, como appresentado no gráfico na parte de baixo da imagem.</p>
# <p>O padrão de onda se repete periodicamente a cada <strong>período</strong> <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-13-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mi>T</mi></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-52" style="width: 0.865em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.742em; height: 0px; font-size: 116%;"><span style="position: absolute; clip: rect(1.358em, 1000.74em, 2.405em, -999.997em); top: -2.214em; left: 0em;"><span class="mrow" id="MathJax-Span-53"><span class="mi" id="MathJax-Span-54" style="font-family: MathJax_Math-italic;">T<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.126em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.22em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.068em; border-left: 0px solid; width: 0px; height: 0.932em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>T</mi></math></span></span><script type="math/tex" id="MathJax-Element-13">T</script>, que representa o intervalo de tempo entre duas oscilações.</p>
# <p>O número de de vezes que uma mesma onda se repete a cada segundo é chamado de <strong>frequência</strong> <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-14-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mi>f</mi></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-55" style="width: 0.68em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.557em; height: 0px; font-size: 116%;"><span style="position: absolute; clip: rect(1.358em, 1000.56em, 2.589em, -999.997em); top: -2.214em; left: 0em;"><span class="mrow" id="MathJax-Span-56"><span class="mi" id="MathJax-Span-57" style="font-family: MathJax_Math-italic;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.065em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.22em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 1.218em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>f</mi></math></span></span><script type="math/tex" id="MathJax-Element-14">f</script>, cuja unidade é o Hz, e é relacionado com o período segundo:</p>
# <p><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-15-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mi>f</mi><mo>=</mo><mn>1</mn><mrow class=&quot;MJX-TeXAtom-ORD&quot;><mo>/</mo></mrow><mi>T</mi></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-58" style="width: 4.313em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.698em; height: 0px; font-size: 116%;"><span style="position: absolute; clip: rect(1.296em, 1003.7em, 2.651em, -999.997em); top: -2.214em; left: 0em;"><span class="mrow" id="MathJax-Span-59"><span class="mi" id="MathJax-Span-60" style="font-family: MathJax_Math-italic;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.065em;"></span></span><span class="mo" id="MathJax-Span-61" style="font-family: MathJax_Main; padding-left: 0.311em;">=</span><span class="mn" id="MathJax-Span-62" style="font-family: MathJax_Main; padding-left: 0.311em;">1</span><span class="texatom" id="MathJax-Span-63"><span class="mrow" id="MathJax-Span-64"><span class="mo" id="MathJax-Span-65" style="font-family: MathJax_Main;">/</span></span></span><span class="mi" id="MathJax-Span-66" style="font-family: MathJax_Math-italic;">T<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.126em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.22em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.354em; border-left: 0px solid; width: 0px; height: 1.289em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>f</mi><mo>=</mo><mn>1</mn><mrow class="MJX-TeXAtom-ORD"><mo>/</mo></mrow><mi>T</mi></math></span></span><script type="math/tex" id="MathJax-Element-15"> f = 1/T </script></p>
# <ul>
# <li>Se a freqüência desse diapasão for de 440 Hz, isto significa que ele vibra 440 vezes em cada segundo! </li>
# </ul>
# <p>Um outro poderia vibrar a 125 Hz e o nosso ouvido detectará essas diferenças como <strong>tonalidades</strong>  diferentes: o de <strong>maior</strong> frequência, soaria mais <strong>agudo</strong>, e o de <strong>menor</strong> frequência soaria mais <strong>grave</strong>. </p>
# <p>No entanto, o ouvido humano só é capaz de ouvir sons que têm frequência entre <strong>20 e 20.000 Hz</strong>.</p>
# <p><img src="http://www.aulas-fisica-quimica.com/imagens/8F_07_01.jpg" alt=""></p>
# <h4 id="amplitude--a"><em>Amplitude <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-16-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mi>A</mi></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-67" style="width: 0.865em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.75em; height: 0px; font-size: 116%;"><span style="position: absolute; clip: rect(1.325em, 1000.75em, 2.359em, -999.997em); top: -2.181em; left: 0em;"><span class="mrow" id="MathJax-Span-68"><span class="mi" id="MathJax-Span-69" style="font-family: MathJax_Math-italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.187em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 0.937em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-16"> A</script></em></h4>
# <p>A amplitude de uma onda refere-se à intensidade da perturbação.</p>
# <p>A unidade utilizada para a medida depende do tipo da onda. No caso de ondas sonoras e sinais de áudio, a unidade utilizada é o decibel (dB). A intensidade sonora é percebida como o "volume" de um som.</p>
# <h4 id="fase--f"><em>Fase <span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-17-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mi>F</mi></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-70" style="width: 0.865em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.75em; height: 0px; font-size: 116%;"><span style="position: absolute; clip: rect(1.325em, 1000.75em, 2.359em, -999.997em); top: -2.181em; left: 0em;"><span class="mrow" id="MathJax-Span-71"><span class="mi" id="MathJax-Span-72" style="font-family: MathJax_Math-italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.118em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.187em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 0.937em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>F</mi></math></span></span><script type="math/tex" id="MathJax-Element-17"> F</script></em></h4>
# <p>Duas ondas estão <strong>em fase</strong> quando suas cristas (topo da onda) das ondas estão alinhadas. Neste caso, ocorre <strong>interferência construtiva</strong>: há formação de uma onda cuja amplitude é a soma das amplitudes das duas ondas.</p>
# <p>Se as ondas estão completamente fora de fase, há <strong>interferência destrutiva</strong>: subtração das amplitudes e destruição da onda.</p>
# <p>Na imagem a seguir estão ilustradas, respectivamente, as interferências construtiva e destrutiva:</p>
# <p><img src="https://www2.ibb.unesp.br/nadi/Museu2_qualidade/Museu2_corpo_humano/Museu2_como_funciona/Museu_homem_nervoso/Museu2_homem_nervoso_audicao/Museu2_qualidade_homem_nervoso_audicao_som_arquivos/image006.jpg" alt=""></p>
# <h3 id="3-passos-fundamentais-do-pds"><strong>3) Passos fundamentais do PDS</strong></h3>
# <p>Para que uma onda sonora possa ser representada no computador, é necessário que ela sofra o processo de <strong>digitalização</strong>, que consiste nos dois passos fundamentais a seguir:</p>
# <ul>
# <li><p>1) <strong>Amostragem/Discretização (Sampling)</strong>: divisão da onda sonora em faixas de igual duração. Normalmente, os áudios são digitalizados a taxas de frequência entre 8kHz e 48kHz. Em um CD, o áudio é digitalizado à taxa de amostragem de 44.1kHz, ou seja, o som é divido em intervalos de 1/44.100 segundos, o que equivale a dizer que há 44.100 amostras de som em um segundo!</p>
# </li>
# <li><p>2) <strong>Quantização (quantizing) e codificação</strong>: cosnsite em tomar a amplitude do som nos pontos em que houve discretização, e armazenar esses valores de amplitude em uma lista numérica. Na quantização uniforme, o sinal é codificado em valores 8 bits (256 níveis) ou 16 bits (65.536 níveis). </p>
# </li>
# </ul>
# <p>Na imagem a seguir, as barras verticais representam a amostragem, que divide a onda sonora em várias faixas de tempo fixado pela taxa de amostragem.</p>
# <p>Os pontos azuis representam a amplitude nos pontos de discretização, que pelo processo de quantização são armazenados no array numérico, a representação digital da onda sonora.</p>
# <img src="https://miro.medium.com/max/1400/0*J7faRuayovpnHnUp.png" width="550/">
#
#
# <h3 id="4-aplicações"><strong>4) Aplicações</strong></h3>
# <p>As principais aplicações de PDS de áudio são:</p>
# <ul>
# <li>1) Reduções de ruído e melhora da qualidade sonora (filtragem digital, gps/gnss, etc.);  </li>
# <li>2) Transmissão, armazenamento e compressão de áudio (wav, mp3, etc.);  </li>
# <li>3) Síntese de voz;  </li>
# <li>4) Análise espectral (FFT); </li>
# <li>5) Reconhecimento de voz.</li>
# </ul>
# <h3 id="5-pds-em-python"><strong>5) PDS em Python</strong></h3>
# <p>A seguir, vamos fazer alguns exemplos de PDS de áudio em Python!</p>
# <p><strong>Gerando um sinal de áudio</strong></p>
# <p>Para gerarmos um sinal de áudio em Python, basta definirmos as características da onda sonora. Vamos construir a onda sonora e visualizá-la a seguir:</p>
# <pre class=" language-python"><code class=" language-python"><span class="token comment"># importando as bibliotecas necessárias</span>
# <span class="token operator">%</span>matplotlib inline
# <span class="token keyword">import</span> numpy <span class="token keyword">as</span> np
# <span class="token keyword">from</span> matplotlib <span class="token keyword">import</span> pyplot <span class="token keyword">as</span> plt
#
# <span class="token comment">#definindo as características da onda sonora</span>
# fs  <span class="token operator">=</span> <span class="token number">44000</span> <span class="token comment"># amostragem de 44kHz. Neste caso, essa taxa será usada para a reprodução do áudio</span>
# A   <span class="token operator">=</span> <span class="token number">2</span>     <span class="token comment"># Amplitude (arbitrário)</span>
# t_i <span class="token operator">=</span> <span class="token number">1</span>     <span class="token comment"># tempo do sinal em segundos</span>
# f0  <span class="token operator">=</span> <span class="token number">1200</span>  <span class="token comment"># 1.2kHz frequência fundamental do áudio, dentro do espectro audível.</span>
# t   <span class="token operator">=</span> np<span class="token punctuation">.</span>arange<span class="token punctuation">(</span><span class="token number">0</span><span class="token punctuation">,</span> t_i<span class="token punctuation">,</span> <span class="token number">1.0</span> <span class="token operator">/</span> fs<span class="token punctuation">)</span> <span class="token comment"># quantização uniforme de fs partes em 1 segundo</span>
#
# <span class="token comment"># definição da onda sonora com as características acima</span>
# wav <span class="token operator">=</span> A <span class="token operator">*</span> np<span class="token punctuation">.</span>sin<span class="token punctuation">(</span><span class="token number">2</span> <span class="token operator">*</span> np<span class="token punctuation">.</span>pi <span class="token operator">*</span> f0 <span class="token operator">*</span> t <span class="token punctuation">)</span> <span class="token comment"># onda senoidal</span>
#
# <span class="token comment"># vamos plotar para ver a onda sonora</span>
# plt<span class="token punctuation">.</span>plot<span class="token punctuation">(</span>t<span class="token punctuation">,</span> wav<span class="token punctuation">)</span>
# plt<span class="token punctuation">.</span>xlabel<span class="token punctuation">(</span><span class="token string">"Tempo (s)"</span><span class="token punctuation">)</span>
# plt<span class="token punctuation">.</span>ylabel<span class="token punctuation">(</span><span class="token string">"Amplitude"</span><span class="token punctuation">)</span>
# plt<span class="token punctuation">.</span>axis<span class="token punctuation">(</span><span class="token punctuation">[</span><span class="token number">0</span><span class="token punctuation">,</span> t_i<span class="token punctuation">,</span> <span class="token operator">-</span>A<span class="token punctuation">,</span> A<span class="token punctuation">]</span><span class="token punctuation">)</span>
# plt<span class="token punctuation">.</span>show<span class="token punctuation">(</span><span class="token punctuation">)</span></code></pre>
# <p><img src="data:image/png;base64,..." alt=""></p>
# <p>Devido à alta frequência do som (há 1200 oscilações em um segundo!), não conseguimos visualizar as oscilações no plot acima, que foi definido em 1 segundo. Vamos ver a seguir como visualizar um pedaço da onda sonora, mas primeiro, vamos ouvir o sinal gerado:</p>
# <p><strong>Reproduzindo o som gerado</strong></p>
# <p>Para reproduzir a onda sonora gerada, basta utilizar a função "Audio" do módulo "IPython.display"</p>
# <pre class=" language-python"><code class=" language-python"><span class="token comment"># importando a função Audio</span>
# <span class="token keyword">from</span> IPython<span class="token punctuation">.</span>display <span class="token keyword">import</span> Audio
# <span class="token comment"># reproduzindo o áudio gerado</span>
# <span class="token comment"># o primeiro argumento é a onda sonora, e o segundo é a taxa de amostragem para a reprodução</span>
# Audio<span class="token punctuation">(</span>wav<span class="token punctuation">,</span> rate<span class="token operator">=</span>fs<span class="token punctuation">)</span></code></pre>
# <p><strong>Visualizando a onda sonora</strong></p>
# <p>Para podermos visualizar a onda sonora em um plot, devemos escolher um intervalo de tempo menor, no qual a onda oscila menos vezes.</p>
# <p>Podemos escolher, por exemplo, um tempo de 0.002 segundos, no qual a onda, como definimos, tem menos de 3 oscilações completas:</p>
# <pre class=" language-python"><code class=" language-python"><span class="token comment"># redefinindo o tempo do sinal para 0.002 segundos</span>
# t_i <span class="token operator">=</span> <span class="token number">0.002</span> <span class="token comment"># max time</span>
#
# <span class="token comment"># redefinindo a onda sonora</span>
# wav <span class="token operator">=</span> A <span class="token operator">*</span> np<span class="token punctuation">.</span>sin<span class="token punctuation">(</span><span class="token number">2</span> <span class="token operator">*</span> np<span class="token punctuation">.</span>pi <span class="token operator">*</span> f0 <span class="token operator">*</span> t<span class="token punctuation">)</span> <span class="token comment"># onda</span>
#
# <span class="token comment"># plotando a onda sonora no intervalo de 0.002 segundos</span>
# plt<span class="token punctuation">.</span>plot<span class="token punctuation">(</span>t<span class="token punctuation">,</span> wav<span class="token punctuation">)</span>
# plt<span class="token punctuation">.</span>xlabel<span class="token punctuation">(</span><span class="token string">"Time"</span><span class="token punctuation">)</span>
# plt<span class="token punctuation">.</span>ylabel<span class="token punctuation">(</span><span class="token string">"Amplitude"</span><span class="token punctuation">)</span>
# plt<span class="token punctuation">.</span>axis<span class="token punctuation">(</span><span class="token punctuation">[</span><span class="token number">0</span><span class="token punctuation">,</span> t_i<span class="token punctuation">,</span> <span class="token operator">-</span>A<span class="token punctuation">,</span> A<span class="token punctuation">]</span><span class="token punctuation">)</span>
# plt<span class="token punctuation">.</span>show<span class="token punctuation">(</span><span class="token punctuation">)</span></code></pre>
# <p><img src="data:image/png;base64,..." alt=""></p>
# <p>Agora sim, conseguimos visualizar a onda sonora que geramos!</p>
# <p><strong>Utilizando o pacote Librosa</strong></p>
# <p>Agora vamos usar o pacote librosa, que facilitará o processamento de arquivos de áudio em Python.</p>
# <p>Para instalar esta biblioteca, execute no terminal:</p>
# <p><code>pip install librosa</code></p>
# <p>Vamos utilizar a librosa para carregar um exemplo de aúdio da própria biblioteca</p>
# <pre class=" language-python"><code class=" language-python"><span class="token comment"># importa a librosa</span>
# <span class="token keyword">import</span> librosa
#
# <span class="token comment">#carrega um áudio padrão de exemplo, através da função "load", com o argumento "librosa.util.example_audio_file()"</span>
# <span class="token comment"># a variável "x" é o tempo, e a "sr" é a amplitude da onda sonora como função do tempo</span>
# <span class="token comment"># podemos especificar a taxa de amostragem com o argumento "sr"</span>
# x <span class="token punctuation">,</span> sr <span class="token operator">=</span> librosa<span class="token punctuation">.</span>load<span class="token punctuation">(</span>librosa<span class="token punctuation">.</span>util<span class="token punctuation">.</span>example_audio_file<span class="token punctuation">(</span><span class="token punctuation">)</span><span class="token punctuation">,</span> sr<span class="token operator">=</span><span class="token number">44100</span><span class="token punctuation">)</span> <span class="token comment"># sampling de 44.1kHz</span></code></pre>
# <p><strong>Visualizando o sinal</strong></p>
# <p>Para visualizarmos o sinal de áudio no gráfico unidimensional de amplitude por tempo (segundos), utilizamos a função "ibrosa.display.waveplot", com os argumentos definidos acima</p>
# <pre class=" language-python"><code class=" language-python"><span class="token comment"># importa o módulo para o plot da onda</span>
# <span class="token keyword">import</span> librosa<span class="token punctuation">.</span>display
# <span class="token comment"># ajusta o tamanho do plot</span>
# plt<span class="token punctuation">.</span>figure<span class="token punctuation">(</span>figsize<span class="token operator">=</span><span class="token punctuation">(</span><span class="token number">14</span><span class="token punctuation">,</span> <span class="token number">5</span><span class="token punctuation">)</span><span class="token punctuation">)</span>
# <span class="token comment"># plota a onda</span>
# librosa<span class="token punctuation">.</span>display<span class="token punctuation">.</span>waveplot<span class="token punctuation">(</span>x<span class="token punctuation">,</span> sr<span class="token operator">=</span>sr<span class="token punctuation">)</span>
# <span class="token comment"># define a label dos eixos</span>
# plt<span class="token punctuation">.</span>xlabel<span class="token punctuation">(</span><span class="token string">'Tempo (s)'</span><span class="token punctuation">)</span>
# plt<span class="token punctuation">.</span>ylabel<span class="token punctuation">(</span><span class="token string">'Amplitude'</span><span class="token punctuation">)</span>
# <span class="token comment"># exibe o plot</span>
# plt<span class="token punctuation">.</span>show<span class="token punctuation">(</span><span class="token punctuation">)</span></code></pre>
# <p><img src="data:image/png;base64,..." alt=""></p>
# <p>Como podemos ver, o áudio qe importamos é bem mais complexo que a onda simples gerada anteriormente. Ainda, é possível ver que o aúdio tem um minuto de duração.</p>
# <p>Vamos ouvir o áudio?</p>
# <p><strong>Reproduzindo o áudio</strong></p>
# <p>Usando a função "Audio", como antes</p>
# <pre class=" language-python"><code class=" language-python">Audio<span class="token punctuation">(</span>librosa<span class="token punctuation">.</span>util<span class="token punctuation">.</span>example_audio_file<span class="token punctuation">(</span><span class="token punctuation">)</span><span class="token punctuation">,</span> rate<span class="token operator">=</span>sr<span class="token punctuation">)</span></code></pre>
# <p>Uma música bem divertida, não é mesmo?</p>
# <p><strong>Salvando o áudio num arquivo .wav</strong></p>
# <p>Por fim, também podemos utilizar a librosa para salvar o áudio como um arquivo .wav:</p>
# <pre class=" language-python"><code class=" language-python"><span class="token comment"># salvando o áudio como um arquivo .wave, com o nome de "tone_220".</span>
# librosa<span class="token punctuation">.</span>output<span class="token punctuation">.</span>write_wav<span class="token punctuation">(</span><span class="token string">'tone_220.wav'</span><span class="token punctuation">,</span> x<span class="token punctuation">,</span> sr<span class="token punctuation">)</span></code></pre>
# </markdown>

# %%
# importando as bibliotecas necessárias
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

#definindo as características da onda sonora
fs  = 44000 # amostragem de 44kHz. Neste caso, essa taxa será usada para a reprodução do áudio
A   = 2     # Amplitude (arbitrário)
t_i = 1     # tempo do sinal em segundos
f0  = 1200  # 1.2kHz frequência fundamental do áudio, dentro do espectro audível.
t   = np.arange(0, t_i, 1.0 / fs) # quantização uniforme de fs partes em 1 segundo

# definição da onda sonora com as características acima
wav = A * np.sin(2 * np.pi * f0 * t ) # onda senoidal

# vamos plotar para ver a onda sonora
plt.plot(t, wav)
plt.xlabel("Tempo (s)")
plt.ylabel("Amplitude")
plt.axis([0, t_i, -A, A])
plt.show()

# %%
# importando as bibliotecas necessárias
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

#definindo as características da onda sonora
fs  = 44000 # amostragem de 44kHz. Neste caso, essa taxa será usada para a reprodução do áudio
A   = 2     # Amplitude (arbitrário)
t_i = 0.002     # tempo do sinal em segundos
f0  = 1200  # 1.2kHz frequência fundamental do áudio, dentro do espectro audível.
t   = np.arange(0, t_i, 1.0 / fs) # quantização uniforme de fs partes em 1 segundo

# definição da onda sonora com as características acima
wav = A * np.sin(2 * np.pi * f0 * t ) # onda senoidal

# vamos plotar para ver a onda sonora
plt.plot(t, wav)
plt.xlabel("Tempo (s)")
plt.ylabel("Amplitude")
plt.axis([0, t_i, -A, A])
plt.show()

# %%
# importando as bibliotecas necessárias
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

#definindo as características da onda sonora
fs  = 44000 # amostragem de 44kHz. Neste caso, essa taxa será usada para a reprodução do áudio
A   = 2     # Amplitude (arbitrário)
t_i = 1     # tempo do sinal em segundos
f0  = 123330  # 1.2kHz frequência fundamental do áudio, dentro do espectro audível.
t   = np.arange(0, t_i, 1.0 / fs) # quantização uniforme de fs partes em 1 segundo

# definição da onda sonora com as características acima
wav = A * np.sin(2 * np.pi * f0 * t ) # onda senoidal

# vamos plotar para ver a onda sonora
plt.plot(t[:1000], wav[:1000])
plt.xlabel("Tempo (s)")
plt.ylabel("Amplitude")
plt.axis([0, t_i, -A, A])
plt.show()

# %%
from vscode_audio import Audio
tempo = np.arange(0, t_i, 1/fs)
fase = 0
frequencia_natural = 1200 #Hz
amplitude = 2

y3 = amplitude * np.sin( 2 * np.pi * frequencia_natural * tempo + fase )
plt.plot(tempo[:1000], y3[:1000])
plt.title(f'f={frequencia_natural}Hz num periodo de 0 a {t_i}s')
plt.xlabel('tempo(s)')
plt.ylabel('amplitude')
Audio(y3, fs)
# Out:
#         <script>
#             if (!window.audioContext) {
#                 window.audioContext = new AudioContext();
#                 window.playAudio = function(audioChannels, sr) {
#                     const buffer = audioContext.createBuffer(audioChannels.length, audioChannels[0].length, sr);
#                     for (let [channel, data] of audioChannels.entries()) {
#                         buffer.copyToChannel(Float32Array.from(data), channel);
#                     }
#                     const source = audioContext.createBufferSource();
#                     source.buffer = buffer;
#                     source.connect(audioContext.destination);
#                     source.start();
#                 }
#             }
#         </script>
# ...

# %%
from vscode_audio import Audio
tempo = np.arange(0, t_i, 1/fs)
fase = 0
frequencia_natural = 200 #Hz
amplitude = 2

y3 = amplitude * np.sin( 2 * np.pi * frequencia_natural * tempo + fase )
plt.plot(tempo[:1000], y3[:1000])
plt.title(f'f={frequencia_natural}Hz num periodo de 0 a {t_i}s')
plt.xlabel('tempo(s)')
plt.ylabel('amplitude')
Audio(y3, fs)
# Out:
#         <script>
#             if (!window.audioContext) {
#                 window.audioContext = new AudioContext();
#                 window.playAudio = function(audioChannels, sr) {
#                     const buffer = audioContext.createBuffer(audioChannels.length, audioChannels[0].length, sr);
#                     for (let [channel, data] of audioChannels.entries()) {
#                         buffer.copyToChannel(Float32Array.from(data), channel);
#                     }
#                     const source = audioContext.createBufferSource();
#                     source.buffer = buffer;
#                     source.connect(audioContext.destination);
#                     source.start();
#                 }
#             }
#         </script>
# ...

# %%
# importando a função Audio
#from IPython.display import Audio

# reproduzindo o áudio gerado
# o primeiro argumento é a onda sonora, e o segundo é a taxa de amostragem para a reprodução
Audio(wav, fs)
# Out:
#         <script>
#             if (!window.audioContext) {
#                 window.audioContext = new AudioContext();
#                 window.playAudio = function(audioChannels, sr) {
#                     const buffer = audioContext.createBuffer(audioChannels.length, audioChannels[0].length, sr);
#                     for (let [channel, data] of audioChannels.entries()) {
#                         buffer.copyToChannel(Float32Array.from(data), channel);
#                     }
#                     const source = audioContext.createBufferSource();
#                     source.buffer = buffer;
#                     source.connect(audioContext.destination);
#                     source.start();
#                 }
#             }
#         </script>
# ...
