# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **1 - Filtro da média**
#
# dst	=	cv2.blur(src, ksize, )
#
# src: imagem input (numpy array)
#
# dst: imagem output (numpy array)
#
# Ksize: tamanho do kernel: (3,3), (5,5), etc.

# %%
img = cv2.imread('text.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
# aplicando o filtro com kernel (3,3)
img_filtro_media_3_3 = cv2.blur( img, ksize=(3,3) )

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(img)
plt.title('original')

plt.subplot(122)
plt.imshow(img_filtro_media_3_3)
plt.title('fitro media 3x3')
# Out:
# Text(0.5, 1.0, 'fitro media 3x3')

# %%
# aplicando o filtro da media com kernel (15,15)
img_filtro_media_15_15 = cv2.blur( img, ksize=(15,15) )

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(img)
plt.title('original')

plt.subplot(122)
plt.imshow(img_filtro_media_15_15)
plt.title('fitro media 15x15')
# Out:
# Text(0.5, 1.0, 'fitro media 15x15')

# %% [markdown]
# # Filtro gaussiano
#
#
# **1 - Filtro Gaussiano**
#
# dst	=	cv2.GaussianBlur(src, ksize, sigmaX, sigmaY)
#
# src: imagem input (numpy array)
#
# dst: imagem output (numpy array)
#
# Ksize: tamanho do kernel gaussiano (tuple): (3,3), (5,5), etc.
#
# sigmaX: Desvio padrão em X
#
# sigmaY: Desvio padrão em Y

# %%
plt.imshow(img)

# %%
img_filtro_gaussiano_3x3 = cv2.GaussianBlur(img, ksize=(3,3), sigmaX=1, sigmaY=1)

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(img)
plt.title('original')

plt.subplot(122)
plt.imshow(img_filtro_gaussiano_3x3)
plt.title('fitro gaussiano 3x3')
# Out:
# Text(0.5, 1.0, 'fitro gaussiano 3x3')

# %% [markdown]
# **1 - Filtro da Mediana**
#
# dst = cv2.medianBlur(src, ksize)
#
# src: imagem input (numpy array)
#
# dst: imagem output (numpy array)
#
# Ksize: tamanho do kernel gaussiano (tuple): (3,3), (5,5), etc.

# %%
img = cv2.imread('filtro_mediano.png',  )
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img_filtro_mediana_5x5 = cv2.medianBlur(img, ksize = 5)

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(img)
plt.title('original')

plt.subplot(122)
plt.imshow(img_filtro_mediana_5x5)
plt.title('fitro mediano 5x5')
# Out:
# Text(0.5, 1.0, 'fitro mediano 5x5')

# %% [markdown]
# ## Operações morfrlógicas - Dilatação

# %%
img = cv2.imread('fechamento.png')
plt.imshow(img)

# %%
# kernel que utilizaremos para dilatação e erosão
kernel = np.ones((3,3))
kernel
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
img_dilatada = cv2.dilate(img, kernel = kernel, iterations=2)

# plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(img)
plt.title('original')

plt.subplot(122)
plt.imshow(img_dilatada)
plt.title('img_dilatada 5x5')
# Out:
# Text(0.5, 1.0, 'img_dilatada 5x5')

# %%
## operação morfológica de Erosão

# %%
img = cv2.imread('jota.png')
plt.imshow(img)

# %%
img_erodido = cv2.erode(img, kernel=kernel, iterations=2)

plt.subplot(121)
plt.imshow(img)
plt.title('original')

plt.subplot(122)
plt.imshow(img_erodido)
plt.title('img_erodido 3x3')
# Out:
# Text(0.5, 1.0, 'img_erodido 3x3')

# %%
img_erodido_dilatado = cv2.dilate(img_erodido, kernel=kernel, iterations=2)

plt.subplot(121)
plt.imshow(img)
plt.title('original')

plt.subplot(122)
plt.imshow(img_erodido_dilatado)
plt.title('img_erodido_dilatado 3x3')
# Out:
# Text(0.5, 1.0, 'img_erodido_dilatado 3x3')
