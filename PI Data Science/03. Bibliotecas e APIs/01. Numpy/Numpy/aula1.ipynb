# %% [markdown]
# # Aula 1

# %%
print('Olá mundo')
# Out:
# Olá mundo

# %% [markdown]
# # Titulo
# ## Subtitullo
# *italico*
# **negrito**
#
# $$\sum_{n=1}^{\infty}\frac{1}{n} = \frac{-1}{12}$$

# %%
# as principais que iremos usar ao longo do curso: o feijão com arroz (bem poderoso!)
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Abaixo alguns exemplos de uso

# %%
df = pd.DataFrame(data=np.random.randn(5,20))

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data=df.corr(), annot=True)

# %%
tips = sns.load_dataset('tips')

# %%
len(tips)
# Out:
# 244

# %%
tips.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
tips.plot(kind='kde', y='total_bill')

# %%
sns.countplot(data=tips, x='sex', hue='smoker')

# %%
sns.boxplot(data=tips, x='tip', hue='smoker')

# %%
tips.groupby('sex')['sex'].count().plot(kind='bar')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.pivot_table(index='day', columns='time', values='total_bill', aggfunc=np.median)
# Out:
# time  Lunch  Dinner
# day
# Thur  16.00  18.780
# Fri   13.42  18.665
# Sat     NaN  18.240
# Sun     NaN  19.630

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.age.median()
# Out:
# 28.0

# %%
titanic.age.mean()
# Out:
# 29.69911764705882

# %% [markdown]
# O operador `!` permite que você acesse comandos do sistema operacional

# %%
# !pip install pandas-datareader
# você pode instalar módulos e bibliotecas direto do jupyter
# Out:
# ...
# You are using pip version 19.0.3, however version 19.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import pandas_datareader as pdr

# %%
petro = pdr.get_data_yahoo('PETR4.SA')

# %%
petro[['High','Low']].plot()

# %%
petro.Low.plot()

# %%
help(pd.DataFrame)
# Out:
# Help on class DataFrame in module pandas.core.frame:
#
# class DataFrame(pandas.core.generic.NDFrame)
#  |  DataFrame(data=None, index=None, columns=None, dtype=None, copy=False)
#  |
#  |  Two-dimensional size-mutable, potentially heterogeneous tabular data
#  |  structure with labeled axes (rows and columns). Arithmetic operations
#  |  align on both row and column labels. Can be thought of as a dict-like
#  |  container for Series objects. The primary pandas data structure.
#  |
#  |  Parameters
#  |  ----------
#  |  data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, or list-like objects
#  |
#  |      .. versionchanged :: 0.23.0
#  |         If data is a dict, argument order is maintained for Python 3.6
#  |         and later.
#  |
#  |  index : Index or array-like
#  |      Index to use for resulting frame. Will default to RangeIndex if
# ...

# %%
# ?pd.DataFrame
# Out:
# Init signature: pd.DataFrame(data=None, index=None, columns=None, dtype=None, copy=False)
# Docstring:
# Two-dimensional size-mutable, potentially heterogeneous tabular data
# structure with labeled axes (rows and columns). Arithmetic operations
# align on both row and column labels. Can be thought of as a dict-like
# container for Series objects. The primary pandas data structure.
#
# Parameters
# ----------
# data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#     Dict can contain Series, arrays, constants, or list-like objects
#
#     .. versionchanged :: 0.23.0
#        If data is a dict, argument order is maintained for Python 3.6
#        and later.
#
# index : Index or array-like
#     Index to use for resulting frame. Will default to RangeIndex if
#     no indexing information part of input data and no index provided
# columns : Index or array-like
#     Column labels to use for resulting frame. Will default to
# ...

# %%
pd.DataFrame

# %% [markdown]
# Um exemplo com o skle

# %%
from sklearn.datasets import load_digits

# %%
dados = load_digits()

# %%
digitos = dados.data
target = dados.target
imagens = dados.images

# %%
imagens[0].shape
# Out:
# (8, 8)

# %%
sns.heatmap(imagens[0], cmap='gray')

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# %%
X = digitos

# %%
y = target

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X,y)

# %%
modelo = MLPClassifier()

# %%
modelo.fit(X_treino, y_treino)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred = modelo.predict(X_teste)

# %%
print(classification_report(y_teste, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        43
#            1       1.00      1.00      1.00        49
#            2       0.98      0.98      0.98        43
#            3       0.96      0.98      0.97        47
#            4       0.98      1.00      0.99        44
#            5       1.00      0.98      0.99        45
#            6       1.00      0.98      0.99        48
#            7       1.00      0.98      0.99        44
#            8       1.00      1.00      1.00        46
#            9       0.98      1.00      0.99        41
#
#    micro avg       0.99      0.99      0.99       450
#    macro avg       0.99      0.99      0.99       450
# weighted avg       0.99      0.99      0.99       450

# %%
accuracy_score(y_teste, y_pred)
# Out:
# 0.9888888888888889
