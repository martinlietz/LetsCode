# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt

img = io.imread('numpy-logo.png') # Carregamento da imagem

print(type(img))

plt.imshow(img) # Exibição da imagem
# Out:
# <class 'numpy.ndarray'>

# %%
alt, larg, n_chan = img.shape

# %%
alt
# Out:
# 200

# %%
larg
# Out:
# 200

# %%
n_chan
# Out:
# 4

# %%
plt.imshow(img[:, :, 0])

# %%
plt.imshow(img[:, :, 1])

# %%
plt.imshow(img[:, :, 2])

# %%
plt.imshow(img[:, :, 3])

# %%
plt.imshow(img[:, :, :])

# %%
plt.imshow(img[:int(alt/2), :, :])

# %%
plt.imshow(img[int(alt/2):, :, :])

# %%
plt.imshow(img[:, :int(larg/2), :])

# %%
plt.imshow(img[:, int(larg/2):, :])
