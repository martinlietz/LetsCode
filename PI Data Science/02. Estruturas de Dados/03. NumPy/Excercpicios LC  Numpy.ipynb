# %% [markdown]
# # Questão #1
# Vale 10
# Enunciado
# Crie uma lista do Python que contenha 10 inteiros aleatórios (entre 0 e 100).
# Em seguida, a partir da lista criada anteriormente, crie um array do Numpy, utilizando a função array.

# %%
import numpy as np
import random

# %%
n = random.sample(range(0, 100), 10)
print(n)
arr = np.array(n)
print(arr)
# Out:
# [64, 38, 83, 94, 75, 42, 13, 59, 66, 43]
# [64 38 83 94 75 42 13 59 66 43]

# %% [markdown]
# # Questão #2
# Vale 10
# Enunciado
# Crie um array com 10 elementos (iniciando em zero),
#  em que os elementos tenham um intervalo de 3 unidades entre si.

# %%
n_elementos  = 10
passo = 3

n = np.arange(0, passo*n_elementos, passo)
print(n)
# Out:
# [ 0  3  6  9 12 15 18 21 24 27]

# %% [markdown]
# #  Questão #3
# Vale 10
# Enunciado
# Crie um array com 40 elementos entre 0 e π.

# %%
arr = np.random.uniform(0,np.pi, size=40)
print(arr)
# Out:
# [2.50469044 0.21356147 3.01840376 2.07095482 2.25810166 2.3360153
#  2.788906   0.42080273 2.44093763 2.63262798 2.60533775 0.09159941
#  1.22639763 1.37366765 1.63562329 1.54840517 0.40975567 3.09253207
#  0.20640993 1.8198746  1.82455792 2.99814083 0.62028792 0.26177447
#  2.77674133 0.04931104 2.4994343  2.41334144 2.73960635 2.87804472
#  0.86020952 0.74261321 0.97552686 2.2482596  0.25992121 2.12210325
#  2.69713479 2.17679976 2.46641316 1.10986579]

# %% [markdown]
# #  Questão #4
# Vale 10
# Enunciado
# Crie um array com 40 elementos, todos iguais a 6.

# %%
arr6 = np.full((1,40), 6,)
print(arr)
# Out:
# [2.50469044 0.21356147 3.01840376 2.07095482 2.25810166 2.3360153
#  2.788906   0.42080273 2.44093763 2.63262798 2.60533775 0.09159941
#  1.22639763 1.37366765 1.63562329 1.54840517 0.40975567 3.09253207
#  0.20640993 1.8198746  1.82455792 2.99814083 0.62028792 0.26177447
#  2.77674133 0.04931104 2.4994343  2.41334144 2.73960635 2.87804472
#  0.86020952 0.74261321 0.97552686 2.2482596  0.25992121 2.12210325
#  2.69713479 2.17679976 2.46641316 1.10986579]

# %% [markdown]
# #  Questão #5
# Vale 10
# Enunciado
# Divida o array obtido na Questão 4 por 3 e,
# em seguida, multiplique-o pelo array obtido na Questão 3.

# %%
arr3 = arr6 // 3
print(arr3)
arrx2 = arr3 * arr
print(arrx2)
# Out:
# [[2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#   2 2 2 2]]
# [[5.00938089 0.42712295 6.03680751 4.14190964 4.51620333 4.67203061
#   5.577812   0.84160545 4.88187527 5.26525596 5.21067551 0.18319881
#   2.45279527 2.74733529 3.27124658 3.09681034 0.81951135 6.18506414
#   0.41281986 3.63974921 3.64911585 5.99628165 1.24057584 0.52354893
#   5.55348267 0.09862209 4.9988686  4.82668288 5.4792127  5.75608943
#   1.72041903 1.48522642 1.95105372 4.49651921 0.51984241 4.24420649
#   5.39426959 4.35359952 4.93282631 2.21973157]]

# %% [markdown]
# #  Questão #6
# Vale 10
# Enunciado
# Crie um array com 40 números aleatórios,
# distribuídos uniformemente, entre [0, 5).
# Em seguida, some-o com o array obtido na Questão 5.
#
# OBS.: Utilize a seed 17 para a criação do array aleatório.

# %%
np.random.seed(17)
arr = np.random.uniform(0,5, size=40)
print(arr)
arsoma = arrx2 + arr
print(arsoma)
# Out:
# [1.47332501 2.65293378 0.95760393 0.33950179 3.9349273  3.28166761
#  3.18760448 2.87801447 0.19531458 1.78906802 4.72841593 0.3002234
#  4.32021052 4.38645263 0.25596833 3.26209308 2.75875684 2.98756627
#  2.41764312 1.4149408  1.48862859 2.80754453 1.98023718 3.94350355
#  2.09242193 0.7195196  0.75453347 0.27620675 3.59018597 1.46158677
#  0.99386936 4.15681961 2.8399556  0.41169875 2.72499287 0.79479372
#  3.38381193 0.59236132 2.22498033 4.43991217]
# [[6.4827059  3.08005672 6.99441145 4.48141143 8.45113063 7.95369821
#   8.76541648 3.71961992 5.07718985 7.05432398 9.93909144 0.48342221
#   6.77300579 7.13378792 3.52721491 6.35890342 3.57826819 9.1726304
#   2.83046299 5.05469001 5.13774444 8.80382618 3.22081302 4.46705248
#   7.64590459 0.81814169 5.75340207 5.10288963 9.06939867 7.21767621
#   2.71428839 5.64204603 4.79100932 4.90821796 3.24483528 5.03900022
#   8.77808151 4.94596085 7.15780664 6.65964374]]

# %% [markdown]
# # Questão #7
# Vale 10
# Enunciado
# Para cada elemento do array da questão anterior, calcule:
#
#   - O seno
#   - O cosseno
#   - O log na base 10
#   - O valor arredondado para inteiro

# %%
import matplotlib.pylab as plt
x = np.linspace(-np.pi, np.pi, 40)
plt.plot(x, np.sin(arsoma[0]) , marker='o')
plt.title("O Seno")
plt.xlabel('Angle [rad]')
plt.ylabel('sin(x)')
plt.axis('tight')
plt.show()

# %%
import matplotlib.pylab as plt
x = np.linspace(-np.pi, np.pi, 40)
plt.plot(x, np.cos(arsoma[0]))
plt.title("O cosseno")
plt.xlabel('Angle [rad]')
plt.ylabel('sin(x)')
plt.axis('tight')
plt.show()

# %%
import matplotlib.pylab as plt
x = np.linspace(-np.pi, np.pi, 40)
plt.plot(x, np.log10(arsoma[0]))
plt.title("log na base 10")
plt.xlabel('Angle [rad]')
plt.ylabel('sin(x)')
plt.axis('tight')
plt.show()

# %%
import matplotlib.pylab as plt
x = np.linspace(-np.pi, np.pi, 40)
plt.plot(x, np.rint(arsoma[0]))
plt.title("valor arredondado para inteiro")
plt.xlabel('Angle [rad]')
plt.ylabel('sin(x)')
plt.axis('tight')
plt.show()

# %% [markdown]
# #  Questão #8
# Vale 10
# Enunciado
# Lembra que você obteve o seno de um array na questão anterior?
# Agora, você deve obter um array apenas com os valores positivos do array resultante daquela operação do seno.

# %%
import seaborn as sns
a = np.where(np.sin(arsoma) > 0, np.sin(arsoma), 0)
a
# Out:
# array([[0.19819946, 0.0614971 , 0.65276314, 0.        , 0.82694206,
#         0.99503242, 0.6126123 , 0.        , 0.        , 0.69695225,
#         0.        , 0.46481195, 0.47046748, 0.75167799, 0.        ,
#         0.07564578, 0.        , 0.24948418, 0.30613426, 0.        ,
#         0.        , 0.58180953, 0.        , 0.        , 0.97842997,
#         0.72987679, 0.        , 0.        , 0.34794598, 0.80429666,
#         0.41441896, 0.        , 0.        , 0.        , 0.        ,
#         0.        , 0.6025532 , 0.        , 0.76730073, 0.36762922]])

# %% [markdown]
# # Questão #9
# Vale 10
# Enunciado
# Para cada elemento do array da questão anterior, calcule:
#
# - O seno
# - O cosseno
# - O log na base 10
# - O valor arredondado para inteiro

# %% [markdown]
# #  Questão #10
# Vale 10
# Enunciado
# Para os dados contidos no array da Q6, obtenha:
#
# - O valor mínimo
# - O valor máximo
# - A posição do valor mínimo
# - A posição do valor máximo
# - A média dos dados
# - A mediana
# - A moda
# - A variância
# - O desvio padrão
# - O array ordenado (forma crescente)

# %%
import statistics
print(f"O valor mínimo {arr.min()} ")
print(f"O valor máximo {arr.max()} ")
print(f"A posição do valor mínimo {arr.argmin()} ")
print(f"A posição do valor máximo {arr.argmax()} ")
print(f"A média dos dados {arr.mean()} ")
print(f"A mediana {np.median(arr)} ")
print(f"A moda {statistics.mode(arr)} ")
print(f"A variância {arr.var()} ")
print(f"O desvio padrão {arr.std()} ")
print(f"O array ordenado (forma crescente) {np.sort(arr)} ")
# Out:
# O valor mínimo 0.1953145809443324
# O valor máximo 4.7284159340920375
# A posição do valor mínimo 0
# A posição do valor máximo 39
# A média dos dados 2.2299948977194917
# A mediana 2.3213117260751774
# A moda 0.1953145809443324
# A variância 1.8966639867749826
# O desvio padrão 1.377194244387836
# O array ordenado (forma crescente) [0.19531458 0.25596833 0.27620675 0.3002234  0.33950179 0.41169875
#  0.59236132 0.7195196  0.75453347 0.79479372 0.95760393 0.99386936
#  1.4149408  1.46158677 1.47332501 1.48862859 1.78906802 1.98023718
#  2.09242193 2.22498033 2.41764312 2.65293378 2.72499287 2.75875684
#  2.80754453 2.8399556  2.87801447 2.98756627 3.18760448 3.26209308
#  3.28166761 3.38381193 3.59018597 3.9349273  3.94350355 4.15681961
#  4.32021052 4.38645263 4.43991217 4.72841593]

# %% [markdown]
# # Questão #11
# Vale 10
# Enunciado
# Crie outro array aleatório, porém,
# dessa vez, com 25 elementos inteiros,
# no intervalo [50, 100).
# Em seguida, converta esse array em uma matriz 5 x 5.

# %%
arr = np.random.randint(50,100, size=25)
arr = arr.reshape(5,5)
print(arr)
# Out:
# [[97 82 70 55 51]
#  [89 74 80 58 98]
#  [55 61 68 78 90]
#  [92 67 72 89 72]
#  [83 97 92 96 74]]

# %% [markdown]
# # Questão #12
# Vale 10
# Enunciado
# Construa a matriz ilustrada pela figura abaixo.
# Em seguida, obtenha os slices (fatiamentos) destacados em cada cor.
# Em outras palavras, utilizando o conceito de slices,
# crie um novo array que contenha os dados destacados em vermelho, azul, roxo e verde
#
# <img src="../../../E1-Q11.png" />

# %%
testeArr = np.arange(0,60).reshape((6,10))[:,:6]
print(testeArr)
arVermelho = testeArr[0,3:5]
print("Vermelho",arVermelho)
arAzul = testeArr[:,2]
print("Azul",arAzul)
arRoxo = testeArr[2::2,::2]
print("Roxo",arRoxo)
arVerde = testeArr[4:,4:]
print("Verde",arVerde)
# Out:
# [[ 0  1  2  3  4  5]
#  [10 11 12 13 14 15]
#  [20 21 22 23 24 25]
#  [30 31 32 33 34 35]
#  [40 41 42 43 44 45]
#  [50 51 52 53 54 55]]
# Vermelho [3 4]
# Azul [ 2 12 22 32 42 52]
# Roxo [[20 22 24]
#  [40 42 44]]
# Verde [[44 45]
#  [54 55]]

# %% [markdown]
# # Questão #13
# Vale 10
# Enunciado
# DESAFIO
#
# Nesse desafio, iremos praticar o conceito de indexação em imagens!
# Pois é, caso você ainda não saiba, as imagens são formadas com conjuntos de pixels,
# e esses pixels são números inteiros (entre 0 e 255).
# Sendo assim, quando carregamos uma imagem no Python,
# essa imagem será armazenada em um matriz (Numpy), ou seja, cada pixel dessa imagem será um elemento dessa matriz.
#
#
# No entanto, é importante que você também saiba que uma imagem colorida é composta por três matrizes,
# visto que uma imagem colorida é formada por 3 cores básicas: vermelho, verde e azul.
# Esse é o famoso padrão RGB. Portanto, sua imagem será armazenada em um array tridimensional.
#
# Sabendo disso, sua missão será carregar uma imagem colorida (em jpg)
# e exibir apenas a metade dessa imagem, tanto na horizontal quanto na vertical.
# Mas, calma... vamos te dar uma ajuda.
#
#
# Primeiro, você precisa instalar a biblioteca skimage para carregar a imagem,
# além da biblioteca do matplotlib para exibir a imagem (veremos essa biblioteca com mais detalhes nesse curso!),
#  caso você ainda não tenha elas instaladas, claro.
#  Para isso, utilize o comando pip install scikit-image matplotlib,
#  se você estiver utilizando o pip, ou conda install scikit-image matplotlib,
#  se estiver utilizando o Anaconda.
#
#
# Em seguida, observe o código abaixo;
# ele te mostra como você pode carregar uma imagem e exibi-la.
#
# Lembrando... Sua missão será carregar uma imagem colorida (em jpg) e exibir apenas a metade dessa imagem,
# tanto na horizontal quanto na vertical.

# %%
from skimage import io, filters, restoration
import numpy as np
import matplotlib.pyplot as plt

img = io.imread('images/numpy-logo.jpg') # Carregamento da imagem
plt.imshow(img) # Exibição da imagem
met = img.copy()
imgss = met[int(met.shape[0])//4:int(met.shape[0] - int(met.shape[0])//4),int(met.shape[1])//4:int(met.shape[1] - int(met.shape[1])//4),:]
imgss = met[:int(met.shape[0] - int(met.shape[0])//2),:int(met.shape[1] - int(met.shape[1])//2),:]
print(met.shape)

plt.imshow(imgss) # Exibição da imagem
# Out:
# (972, 2560, 3)

# %%
import numpy as np
from scipy.io.wavfile import write
import sounddevice as sd

fs = 44100
data = np.random.uniform(-1, 1, fs)
# sd.play(data, fs)
framerate = 44100
t = np.linspace(0,5,framerate*5)
# Can also do stereo or more channels
dataleft = np.sin(2*np.pi*220*t)
dataright = np.sin(2*np.pi*224*t)
sd.play(dataleft, fs)

data = np.random.uniform(-1,1,44100) # 44100 random samples between -1 and 1
scaled = np.int16(data/np.max(np.abs(data)) * 32767)

write('test.wav', 44100, scaled)
#  Audio(filename="test.wav")
#sd.play(url="http://www.w3schools.com/html/horse.ogg")
