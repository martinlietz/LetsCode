# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mysql.connector as mysql
from sqlalchemy import create_engine
import pandas as pd

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
iris.plot(kind='scatter',x='petal_length', y='petal_width')

# %%
sns.scatterplot(data=iris, x='petal_length', y='petal_width', hue='species')

# %%
# fazer a classificacao KNN os K mais proximos 
# x = atributos
# y = dados

# %%
X = iris.drop('species', axis=1)
y = iris['species']

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X,y)

# %%
modelo = KNeighborsClassifier()

# %%
modelo.fit(X_treino,y_treino)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
#este e o comando para predicoes

# %%
y_pred = modelo.predict(X_teste)

# %%
cancer = pd.read_csv('cancerMama.csv')

# %%
cancer
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 5      843786         M       12.450         15.70           82.57      477.1
# 6      844359         M       18.250         19.98          119.60     1040.0
# 7    84458202         M       13.710         20.83           90.20      577.9
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# ...

# %%
cancer.head(2)
# Out:
#        id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302         M        17.99         10.38           122.8     1001.0
# 1  842517         M        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
#
#       ...       texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0     ...               17.33            184.6      2019.0            0.1622
# 1     ...               23.41            158.8      1956.0            0.1238
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
#
#    fractal_dimension_worst  Unnamed: 32
# ...

# %%
#tratando os dados - usando coluna 0 ate a 32

# %%
cancer = pd.read_csv('cancerMama.csv', index_col=0, usecols=range(0,32))

# %%
X = cancer.drop('diagnosis', axis=1)
y = cancer['diagnosis']

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X,y)

# %%
Modelo = KNeighborsClassifier()

# %%
Modelo.fit(X_treino, y_treino)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_pred= Modelo.predict(X_teste)

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
print (classification_report(y_teste, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.93      0.99      0.96        94
#            M       0.98      0.86      0.91        49
#
#    micro avg       0.94      0.94      0.94       143
#    macro avg       0.95      0.92      0.94       143
# weighted avg       0.95      0.94      0.94       143

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
modelo.classes_
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
confusion_matrix(y_teste, y_pred)
# Out:
# array([[93,  1],
#        [ 7, 42]], dtype=int64)

# %%
accuracy_score(y_teste, y_pred)
# Out:
# 0.9440559440559441

# %%
iris = sns.load_dataset('iris')

# %%
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
X = iris.drop('species', axis=1)
y = iris['species']

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X,y)

# %%
modelo = KNeighborsClassifier()

# %%
modelo.fit(X_treino, y_treino)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_pred = modelo.predict(X_teste)

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
accuracy_score(y_teste, y_pred)
# Out:
# 0.9473684210526315

# %%
print(classification_report(y_teste, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        14
#   versicolor       0.92      0.92      0.92        12
#    virginica       0.92      0.92      0.92        12
#
#    micro avg       0.95      0.95      0.95        38
#    macro avg       0.94      0.94      0.94        38
# weighted avg       0.95      0.95      0.95        38

# %%
confusion_matrix(y_teste, y_pred)
# Out:
# array([[14,  0,  0],
#        [ 0, 11,  1],
#        [ 0,  1, 11]], dtype=int64)

# %%
len(cancer)
# Out:
# 569

# %%
X = cancer.drop('diagnosis', axis=1)
y = cancer['diagnosis']
X_treino, X_teste, y_treino, y_teste = train_test_split(X,y)

# %%
for k in range (2,20):  #escolhido de 2 a 20, poderia ser toda a lista ou qq outro range
    modelo = KNeighborsClassifier(n_neighbors=k)
    modelo.fit(X_treino, y_treino)
    y_pred = modelo.predict(X_teste)
    print('viz.:',k,'accuracia:',accuracy_score(y_teste, y_pred))
# Out:
# viz.: 2 accuracia: 0.9090909090909091
# viz.: 3 accuracia: 0.9300699300699301
# viz.: 4 accuracia: 0.916083916083916
# viz.: 5 accuracia: 0.9230769230769231
# viz.: 6 accuracia: 0.916083916083916
# viz.: 7 accuracia: 0.916083916083916
# viz.: 8 accuracia: 0.916083916083916
# viz.: 9 accuracia: 0.9300699300699301
# viz.: 10 accuracia: 0.916083916083916
# viz.: 11 accuracia: 0.9230769230769231
# viz.: 12 accuracia: 0.916083916083916
# viz.: 13 accuracia: 0.916083916083916
# viz.: 14 accuracia: 0.9230769230769231
# viz.: 15 accuracia: 0.9230769230769231
# viz.: 16 accuracia: 0.9230769230769231
# viz.: 17 accuracia: 0.9230769230769231
# viz.: 18 accuracia: 0.9230769230769231
# viz.: 19 accuracia: 0.9230769230769231

# %%
# achando o cotovelo da curva

# %%
viz = []
acc = []
for k in range (2,len(X_treino)): # selecionado toda a lista
    modelo = KNeighborsClassifier(n_neighbors=k)
    modelo.fit(X_treino, y_treino)
    y_pred = modelo.predict(X_teste)
    viz.append(k)
    acc.append(accuracy_score(y_teste, y_pred))

# %%
plt.plot(viz,acc)

# %%
def sub(x,y):
    return x - y

# %%
sub(5,3)
# Out:
# 2

# %%
args = {'x':5,'y':3}

# %%
sub(**args)
# Out:
# 2

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV

# %%
modelo = KNeighborsClassifier()

# %%
from sklearn.model_selection import GridSearchCV

# %%
paran_knn = {'n_neighbors':range(2,30),'metric':['manhattan','euclidean']}

# %%
grid = GridSearchCV(estimator = modelo, param_grid = paran_knn, scoring = 'accuracy')

# %%
grid.fit(X_treino, y_treino)
# Out:
# C:\Users\br003e\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'n_neighbors': range(2, 30), 'metric': ['manhattan', 'euclidean']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
grid.best_params_
# Out:
# {'metric': 'manhattan', 'n_neighbors': 3}

# %%
melhor_modelo = grid.best_estimator_

# %%
grid.best_score_
# Out:
# 0.9436619718309859

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
paran_knn = {'n_neighbors':range(2,30),'metric':['manhattan','euclidean']}

# %%
grid = GridSearchCV(estimator = modelo, param_grid = paran_knn, scoring = 'accuracy')

# %%
x = iris.drop('species', axis=1)
y = iris['species']
X_treino, X_teste, y_treino, y_teste = train_test_split(X,y)

# %%
grid.fit(X_treino, y_treino)
# Out:
# C:\Users\br003e\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\br003e\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#            metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#            weights='uniform'),
#        fit_params=None, iid='warn', n_jobs=None,
# ...

# %%
# modelo=KNeighborsClassifier(**grid.best_params_)

# %%
# OU
modelo = grid.best_estimator_

# %%
y_pred = modelo.predict(X_teste)

# %%
accuracy_score(y_teste, y_pred)
# Out:
# 0.8947368421052632

# %%
from sklearn.model_selection import cross_val_score

# %%
modelo = KNeighborsClassifier()

# %%
cv = cross_val_score(estimator=modelo, X=X, y=y, scoring='accuracy', cv=10)

# %%
cv
# Out:
# array([1.        , 0.93333333, 1.        , 1.        , 0.86666667,
#        0.93333333, 0.93333333, 1.        , 1.        , 1.        ])

# %%
# N O R A M L I Z A C A O     DOS    D A D O S

# %%
vinhos = pd.read_csv('vinhos.csv')

# %%
vinhos.head(2)
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# 1             4.38  1.05                          3.40     1050
